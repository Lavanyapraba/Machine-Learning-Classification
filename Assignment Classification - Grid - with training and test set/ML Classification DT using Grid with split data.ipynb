# %%
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['User ID', 'Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
Independent=dataset[[ 'Age', 'EstimatedSalary','Gender_Male']]

# %%
Independent.shape
# Out:
# (400, 3)

# %%
Independent
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
Dependent=dataset[["Purchased"]]

# %%
Dependent
# Out:
#      Purchased
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 395          1
# 396          1
# 397          1
# 398          0
# 399          1
#
# [400 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
x_train,x_test,y_train,y_test=train_test_split(Independent,Dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_test=sc.fit_transform(x_test)
x_train=sc.transform(x_train)

# %%
from sklearn.tree import DecisionTreeClassifier
param_grid={'criterion':['gini','entropy','log_loss'],'splitter':['best','random'],'max_features':['sqrt','log2']}
grid=GridSearchCV(DecisionTreeClassifier(),param_grid,verbose=3,refit=True,n_jobs=-1,cv=5)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
y_pred=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,roc_auc_score

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
print(cm)
# Out:
# [[70  9]
#  [ 5 36]]

# %%
clf_rpt=classification_report(y_test,y_pred)

# %%
print(clf_rpt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91        79
#            1       0.80      0.88      0.84        41
#
#     accuracy                           0.88       120
#    macro avg       0.87      0.88      0.87       120
# weighted avg       0.89      0.88      0.88       120

# %%
roc_score=roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])

# %%
roc_score
# Out:
# 0.8820623649274467

# %%
re=grid.cv_results_

# %%
print("The best parameters are:", grid.best_params_)
# Out:
# The best parameters are: {'criterion': 'gini', 'max_features': 'sqrt', 'splitter': 'random'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009147      0.001993         0.008661        0.001796
# 1        0.005847      0.001853         0.007926        0.002759
# 2        0.006901      0.000531         0.009237        0.000992
# 3        0.006135      0.001756         0.008164        0.001471
# 4        0.006641      0.002814         0.007619        0.001940
# 5        0.005151      0.001734         0.007395        0.001790
# 6        0.006530      0.002577         0.006909        0.001328
# 7        0.007149      0.001311         0.007781        0.001259
# 8        0.005982      0.001423         0.008461        0.000781
# 9        0.005621      0.001017         0.007604        0.001343
# 10       0.005594      0.001403         0.008863        0.002444
# 11       0.006079      0.001551         0.008667        0.001685
#
#    param_criterion param_max_features param_splitter  \
# 0             gini               sqrt           best
# 1             gini               sqrt         random
# 2             gini               log2           best
# 3             gini               log2         random
# 4          entropy               sqrt           best
# 5          entropy               sqrt         random
# 6          entropy               log2           best
# 7          entropy               log2         random
# 8         log_loss               sqrt           best
# 9         log_loss               sqrt         random
# 10        log_loss               log2           best
# 11        log_loss               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.821429
# 1   {'criterion': 'gini', 'max_features': 'sqrt', ...           0.875000
# 2   {'criterion': 'gini', 'max_features': 'log2', ...           0.857143
# 3   {'criterion': 'gini', 'max_features': 'log2', ...           0.839286
# 4   {'criterion': 'entropy', 'max_features': 'sqrt...           0.821429
# 5   {'criterion': 'entropy', 'max_features': 'sqrt...           0.839286
# 6   {'criterion': 'entropy', 'max_features': 'log2...           0.839286
# 7   {'criterion': 'entropy', 'max_features': 'log2...           0.839286
# 8   {'criterion': 'log_loss', 'max_features': 'sqr...           0.875000
# 9   {'criterion': 'log_loss', 'max_features': 'sqr...           0.839286
# 10  {'criterion': 'log_loss', 'max_features': 'log...           0.785714
# 11  {'criterion': 'log_loss', 'max_features': 'log...           0.839286
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.821429           0.839286           0.803571
# 1            0.821429           0.875000           0.875000
# 2            0.821429           0.803571           0.857143
# 3            0.857143           0.821429           0.875000
# 4            0.875000           0.821429           0.821429
# 5            0.803571           0.839286           0.803571
# 6            0.821429           0.839286           0.821429
# 7            0.803571           0.803571           0.821429
# 8            0.821429           0.821429           0.839286
# 9            0.875000           0.803571           0.857143
# 10           0.857143           0.821429           0.857143
# 11           0.750000           0.803571           0.803571
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.892857         0.835714        0.030723                7
# 1            0.910714         0.871429        0.028571                1
# 2            0.892857         0.846429        0.031135                4
# 3            0.821429         0.842857        0.020825                5
# 4            0.892857         0.846429        0.031135                3
# 5            0.821429         0.821429        0.015972               12
# 6            0.875000         0.839286        0.019562                6
# 7            0.875000         0.828571        0.026726               10
# 8            0.910714         0.853571        0.034626                2
# 9            0.785714         0.832143        0.033120                8
# 10           0.839286         0.832143        0.026726                9
# 11           0.910714         0.821429        0.052973               11
